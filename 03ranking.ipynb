# %% [markdown]
# # Ejercicio 03: Cálculo de Relevancia y Ranking de Documentos
#
# El objetivo de este ejercicio es calcular analíticamente la relevancia de cada documento en un corpus y luego ordenar (rankear) los documentos basándonos en esa puntuación de relevancia para tres consultas específicas. Seguirás los siguientes pasos:

# %%
import xml.etree.ElementTree as ET
import numpy as np
import re
from collections import Counter

# %% [markdown]
# ### Procesamiento del Corpus:
#
# - Leer y parsear el archivo XML proporcionado que contiene el corpus de documentos con sus metadatos (keywords, autor y fecha).

# %%
# Cargar y analizar el contenido del archivo XML
arbol_xml = ET.parse('/content/sample_data/03ranking_corpus.xml')
raiz = arbol_xml.getroot()

# Crear una lista para almacenar la información de los textos y sus metadatos
lista_documentos = []

# Recorrer cada nodo 'documento' dentro del archivo XML
for nodo in raiz.findall('document'):
    identificador = nodo.get('id')
    titulo = nodo.find('title').text
    palabras_clave = nodo.find('keywords').text
    autor = nodo.find('author').text
    fecha = nodo.find('date').text

    # Añadir los metadatos del documento a la lista
    lista_documentos.append({
        'id': identificador,
        'titulo': titulo,
        'palabras_clave': palabras_clave,
        'autor': autor,
        'fecha': fecha
    })

# %%
# Mostrar la información de cada documento en la lista
for doc in lista_documentos:
    print(f"Identificador: {doc['id']}")
    print(f"Título: {doc['titulo']}")
    print(f"Palabras clave: {doc['palabras_clave']}")
    print(f"Autor: {doc['autor']}")
    print(f"Fecha: {doc['fecha']}")
    print("-" * 40)
# Out:
# Identificador: 1
# Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
# Palabras clave: telemedicina, salud crónica, tratamiento, tecnología médica
# Autor: Dr. Juan Pérez
# Fecha: 2023-01-15
# ----------------------------------------
# Identificador: 2
# Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
# Palabras clave: nutrición, rendimiento académico, salud mental, estudiantes
# Autor: Dra. María López
# Fecha: 2023-02-10
# ----------------------------------------
# Identificador: 3
# Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
# Palabras clave: amistad, bienestar estudiantil, campus, relaciones sociales
# Autor: Miguel Rodríguez
# Fecha: 2023-03-05
# ----------------------------------------
# Identificador: 4
# Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
# Palabras clave: bibliotecas universitarias, investigación, academia, recursos
# Autor: Lucía Martínez
# Fecha: 2023-04-20
# ----------------------------------------
# Identificador: 5
# Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
# Palabras clave: espacios verdes, campus universitario, concentración, estrés
# Autor: Carlos Fernández
# Fecha: 2023-05-15
# ----------------------------------------
# Identificador: 6
# Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
# Palabras clave: cultura universitaria, hábitos saludables, bienestar, estudiantes
# Autor: Ana Sánchez
# Fecha: 2023-06-10
# ----------------------------------------
# Identificador: 7
# Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
# Palabras clave: sueño, salud mental, rendimiento académico, universitarios
# Autor: Javier Torres
# Fecha: 2023-07-25
# ----------------------------------------
# Identificador: 8
# Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
# Palabras clave: apoyo familiar, apoyo social, bienestar emocional, estudiantes
# Autor: Laura Gómez
# Fecha: 2023-08-30
# ----------------------------------------
# Identificador: 9
# Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
# Palabras clave: hábitos de lectura, desarrollo cognitivo, jóvenes, adultos
# Autor: Fernando Ruiz
# Fecha: 2023-09-18
# ----------------------------------------
# Identificador: 10
# Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
# Palabras clave: tecnología médica, medicina preventiva, jóvenes, avances tecnológicos
# Autor: Elena Navarro
# Fecha: 2023-10-05
# ----------------------------------------
# Identificador: 11
# Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
# Palabras clave: ejercicio, estrés académico, estudiantes universitarios, salud
# Autor: Diego Castro
# Fecha: 2023-11-12
# ----------------------------------------
# Identificador: 12
# Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
# Palabras clave: mindfulness, meditación, ansiedad, estudiantes universitarios
# Autor: Sofía Vega
# Fecha: 2023-12-01
# ----------------------------------------
# Identificador: 13
# Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
# Palabras clave: salud mental, estudiantes universitarios, apoyo psicológico, grupos de estudio
# Autor: Marcos Ortiz
# Fecha: 2024-01-10
# ----------------------------------------
# Identificador: 14
# Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
# Palabras clave: salud mental, desempeño académico, servicios universitarios, estudiantes
# Autor: Paula Morales
# Fecha: 2024-02-15
# ----------------------------------------
# Identificador: 15
# Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
# Palabras clave: actividades extracurriculares, bienestar emocional, social, estudiantes
# Autor: José Herrera
# Fecha: 2024-03-05
# ----------------------------------------
# Identificador: 16
# Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
# Palabras clave: laboratorios de innovación, competencias tecnológicas, educación, desarrollo
# Autor: Andrea Díaz
# Fecha: 2024-04-20
# ----------------------------------------
# Identificador: 17
# Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
# Palabras clave: diseño de campus, interacción, colaboración, tendencias
# Autor: Sergio Muñoz
# Fecha: 2024-05-15
# ----------------------------------------
# Identificador: 18
# Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
# Palabras clave: bienestar académico, estudiantes que trabajan, comparación, rendimiento
# Autor: Isabel Flores
# Fecha: 2024-06-10
# ----------------------------------------
# Identificador: 19
# Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
# Palabras clave: agotamiento académico, factores de riesgo, prevención, estudiantes universitarios
# Autor: Ricardo Ramos
# Fecha: 2024-07-25
# ----------------------------------------
# Identificador: 20
# Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
# Palabras clave: tecnología, redes sociales, calidad del sueño, estudiantes
# Autor: Valeria Castillo
# Fecha: 2024-08-30
# ----------------------------------------
# Identificador: 21
# Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
# Palabras clave: tecnologías verdes, edificios universitarios, impacto ambiental, sostenibilidad
# Autor: Daniel Medina
# Fecha: 2024-09-18
# ----------------------------------------
# Identificador: 22
# Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
# Palabras clave: bicicletas compartidas, movilidad, universidades, transporte sostenible
# Autor: Patricia Reyes
# Fecha: 2024-10-05
# ----------------------------------------
# Identificador: 23
# Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
# Palabras clave: carga académica, salud emocional, estudiantes, apoyo universitario
# Autor: Gonzalo Soto
# Fecha: 2024-11-12
# ----------------------------------------
# Identificador: 24
# Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
# Palabras clave: equilibrio, vida social, académica, estudiantes, estrategias
# Autor: Camila Aguilar
# Fecha: 2024-12-01
# ----------------------------------------
# Identificador: 25
# Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
# Palabras clave: actividades artísticas, bienestar psicológico, vida universitaria, creatividad
# Autor: Adrián Vargas
# Fecha: 2025-01-10
# ----------------------------------------
# Identificador: 26
# Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
# Palabras clave: programas de becas, retención de estudiantes, beneficios, universidades
# Autor: Teresa Romero
# Fecha: 2025-02-15
# ----------------------------------------
# Identificador: 27
# Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
# Palabras clave: deportes, actividad física, integración social, estudiantes
# Autor: Alberto Peña
# Fecha: 2025-03-05
# ----------------------------------------
# Identificador: 28
# Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
# Palabras clave: eventos de bienestar, talleres, reducción del estrés, universidad
# Autor: Silvia Campos
# Fecha: 2025-04-20
# ----------------------------------------
# Identificador: 29
# Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
# Palabras clave: hábitos de sueño, rendimiento en exámenes, análisis, estudiantes
# Autor: Óscar Luna
# Fecha: 2025-05-15
# ----------------------------------------
# Identificador: 30
# Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
# Palabras clave: inteligencia artificial, servicios médicos, comunidades remotas, tecnología
# Autor: María Paredes
# Fecha: 2025-06-10
# ----------------------------------------

# %% [markdown]
# ### Procesamiento de las Consultas:
#
# - Definir las consultas proporcionadas.
# - Extraer las palabras clave de cada consulta.

# %%
# Definir las preguntas
preguntas = {
    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",
    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",
    3: "Estrategias universitarias para reducir el estrés en estudiantes"
}

# Función para analizar el texto y extraer términos clave
def analizar_texto(texto):
    # Convertir el texto a minúsculas
    texto = texto.lower()
    # Sustituir caracteres no alfanuméricos por espacios
    import re
    texto = re.sub(r'[^a-záéíóúñü]+', ' ', texto)
    # Dividir en tokens y eliminar espacios adicionales
    tokens = texto.strip().split()
    return set(tokens)

# %%
# Mostrar los términos clave extraídos de cada pregunta
for id_pregunta, texto_pregunta in preguntas.items():
    # Analizar el texto de la pregunta
    palabras_clave = analizar_texto(texto_pregunta)
    print(f"Pregunta {id_pregunta}: {palabras_clave}")
# Out:
# Pregunta 1: {'la', 'de', 'estudiantes', 'universitarios', 'mental', 'impacto', 'en', 'el', 'salud', 'académico', 'los', 'rendimiento'}
# Pregunta 2: {'emocional', 'extracurriculares', 'en', 'el', 'bienestar', 'campus', 'actividades', 'universitario', 'y'}
# Pregunta 3: {'estrategias', 'estudiantes', 'estrés', 'en', 'el', 'universitarias', 'para', 'reducir'}

# %% [markdown]
# ### Cálculo de Relevancia:
# - Calcular la puntuación de relevancia para cada documento del corpus respecto a cada consulta.
# - Utilizar métricas de similitud (Similitud Coseno y Jaccard) entre la representación vectorial de los documentos y las de las consultas.

# %%
# Función para calcular la similitud coseno
def calcular_similitud_coseno(pregunta, documento):
    # Extraer términos clave de la pregunta y el documento
    tokens_pregunta = analizar_texto(pregunta)
    tokens_documento = analizar_texto(documento)

    # Generar el vocabulario combinado (palabras únicas de ambos conjuntos)
    vocabulario = list(tokens_pregunta | tokens_documento)  # Unión de los conjuntos

    # Construir los vectores binarios de frecuencia
    vector_pregunta = [1 if palabra in tokens_pregunta else 0 for palabra in vocabulario]
    vector_documento = [1 if palabra in tokens_documento else 0 for palabra in vocabulario]

    # Calcular el producto punto y las normas de los vectores
    producto_punto = np.dot(vector_pregunta, vector_documento)
    norma_pregunta = np.linalg.norm(vector_pregunta)
    norma_documento = np.linalg.norm(vector_documento)

    # Retornar la similitud coseno
    if norma_pregunta == 0 or norma_documento == 0:
        return 0  # No hay similitud si alguno de los vectores es cero
    return producto_punto / (norma_pregunta * norma_documento)

# %%
# Función para calcular la similitud de Jaccard
def calcular_similitud_jaccard(pregunta, documento):
    # Obtener los conjuntos de términos clave de la pregunta y el documento
    tokens_pregunta = analizar_texto(pregunta)
    tokens_documento = analizar_texto(documento)

    # Calcular la intersección y unión de los conjuntos
    interseccion = tokens_pregunta & tokens_documento
    union = tokens_pregunta | tokens_documento

    # Retornar la similitud de Jaccard
    return len(interseccion) / len(union) if union else 0

# %%
# Evaluar la relevancia de cada documento en relación con cada pregunta
for id_pregunta, texto_pregunta in preguntas.items():
    print(f"Pregunta {id_pregunta}: {texto_pregunta}")

    for documento in lista_documentos:
        texto_documento = documento['titulo'] + ' ' + documento['palabras_clave']

        # Calcular similitud coseno entre la pregunta y el documento
        puntuacion_coseno = calcular_similitud_coseno(texto_pregunta, texto_documento)

        # Calcular similitud de Jaccard entre la pregunta y el documento
        puntuacion_jaccard = calcular_similitud_jaccard(texto_pregunta, texto_documento)

        # Mostrar los resultados
        print(f"  Documento {documento['id']}: {documento['titulo']}")
        print(f"    Similitud Coseno: {puntuacion_coseno:.4f}")
        print(f"    Similitud de Jaccard: {puntuacion_jaccard:.4f}")
    print("\n")
# Out:
# Pregunta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.3203
#     Similitud de Jaccard: 0.1905
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.6405
#     Similitud de Jaccard: 0.4706
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.3501
#     Similitud de Jaccard: 0.2083
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.3203
#     Similitud de Jaccard: 0.1905
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.3608
#     Similitud de Jaccard: 0.2174
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.4804
#     Similitud de Jaccard: 0.3158
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.6405
#     Similitud de Jaccard: 0.4706
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.5217
#     Similitud de Jaccard: 0.3500
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.4167
#     Similitud de Jaccard: 0.2632
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1601
#     Similitud de Jaccard: 0.0870
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.6172
#     Similitud de Jaccard: 0.4444
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.4804
#     Similitud de Jaccard: 0.3158
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.5809
#     Similitud de Jaccard: 0.3913
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.6301
#     Similitud de Jaccard: 0.4500
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.3203
#     Similitud de Jaccard: 0.1905
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.3333
#     Similitud de Jaccard: 0.2000
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.3203
#     Similitud de Jaccard: 0.1905
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.3727
#     Similitud de Jaccard: 0.2273
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.4629
#     Similitud de Jaccard: 0.3000
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.4629
#     Similitud de Jaccard: 0.3000
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.4472
#     Similitud de Jaccard: 0.2857
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.2981
#     Similitud de Jaccard: 0.1739
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.3693
#     Similitud de Jaccard: 0.2143
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.2402
#     Similitud de Jaccard: 0.1364
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.2402
#     Similitud de Jaccard: 0.1364
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.4352
#     Similitud de Jaccard: 0.2778
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.4629
#     Similitud de Jaccard: 0.3000
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2722
#     Similitud de Jaccard: 0.1538
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.5217
#     Similitud de Jaccard: 0.3500
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.2236
#     Similitud de Jaccard: 0.1250
#
#
# Pregunta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.0925
#     Similitud de Jaccard: 0.0476
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.2774
#     Similitud de Jaccard: 0.1579
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.3234
#     Similitud de Jaccard: 0.1818
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.1849
#     Similitud de Jaccard: 0.1000
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.4167
#     Similitud de Jaccard: 0.2500
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.3698
#     Similitud de Jaccard: 0.2222
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.2774
#     Similitud de Jaccard: 0.1579
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.4303
#     Similitud de Jaccard: 0.2632
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.2887
#     Similitud de Jaccard: 0.1667
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1849
#     Similitud de Jaccard: 0.1000
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.0891
#     Similitud de Jaccard: 0.0455
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.2774
#     Similitud de Jaccard: 0.1579
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.2981
#     Similitud de Jaccard: 0.1600
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.1617
#     Similitud de Jaccard: 0.0833
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.5547
#     Similitud de Jaccard: 0.3750
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.1925
#     Similitud de Jaccard: 0.1053
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.3698
#     Similitud de Jaccard: 0.2222
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.3443
#     Similitud de Jaccard: 0.2000
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.2673
#     Similitud de Jaccard: 0.1500
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.2673
#     Similitud de Jaccard: 0.1500
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.1721
#     Similitud de Jaccard: 0.0909
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.1721
#     Similitud de Jaccard: 0.0909
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.2132
#     Similitud de Jaccard: 0.1071
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.1849
#     Similitud de Jaccard: 0.1000
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.4623
#     Similitud de Jaccard: 0.2941
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.1005
#     Similitud de Jaccard: 0.0526
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.3563
#     Similitud de Jaccard: 0.2105
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2357
#     Similitud de Jaccard: 0.1250
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.2582
#     Similitud de Jaccard: 0.1429
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.1721
#     Similitud de Jaccard: 0.0909
#
#
# Pregunta 3: Estrategias universitarias para reducir el estrés en estudiantes
#   Documento 1: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.1961
#     Similitud de Jaccard: 0.1053
#   Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 3: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.2572
#     Similitud de Jaccard: 0.1364
#   Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.3536
#     Similitud de Jaccard: 0.2000
#   Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.1961
#     Similitud de Jaccard: 0.1053
#   Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.2739
#     Similitud de Jaccard: 0.1500
#   Documento 9: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.2041
#     Similitud de Jaccard: 0.1111
#   Documento 10: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.1961
#     Similitud de Jaccard: 0.1053
#   Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.2835
#     Similitud de Jaccard: 0.1579
#   Documento 12: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.3953
#     Similitud de Jaccard: 0.2174
#   Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.2572
#     Similitud de Jaccard: 0.1364
#   Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 16: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.2041
#     Similitud de Jaccard: 0.1111
#   Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.2942
#     Similitud de Jaccard: 0.1667
#   Documento 18: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.2739
#     Similitud de Jaccard: 0.1500
#   Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.4725
#     Similitud de Jaccard: 0.2941
#   Documento 20: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.2835
#     Similitud de Jaccard: 0.1579
#   Documento 21: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.1826
#     Similitud de Jaccard: 0.0952
#   Documento 22: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.2739
#     Similitud de Jaccard: 0.1500
#   Documento 23: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.1508
#     Similitud de Jaccard: 0.0714
#   Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.3922
#     Similitud de Jaccard: 0.2353
#   Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.1961
#     Similitud de Jaccard: 0.1053
#   Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.3198
#     Similitud de Jaccard: 0.1875
#   Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.2835
#     Similitud de Jaccard: 0.1579
#   Documento 28: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.2500
#     Similitud de Jaccard: 0.1304
#   Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.2739
#     Similitud de Jaccard: 0.1500
#   Documento 30: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.1826
#     Similitud de Jaccard: 0.0952

# %% [markdown]
# ### Ranking de Documentos:
#
# - Ordenar los documentos en función de su puntuación de relevancia de mayor a menor.
# - Mostrar el ranking de documentos para cada consulta.

# %%
# Definir el número máximo de documentos a incluir en el ranking
limite_ranking = 7

# Diccionario para almacenar los rankings de relevancia de cada pregunta
rankings_relevancia = {}

# Iterar sobre cada pregunta para calcular similitudes y generar el ranking
for id_pregunta, texto_pregunta in preguntas.items():
    # Lista para almacenar los documentos junto con sus puntuaciones de relevancia
    puntuaciones_relevancia = []

    # Recorrer cada documento del corpus
    for documento in lista_documentos:
        # Crear el texto del documento concatenando título y palabras clave
        texto_documento = documento['titulo'] + ' ' + documento['palabras_clave']

        # Calcular similitud coseno y Jaccard utilizando las funciones definidas
        puntuacion_coseno = calcular_similitud_coseno(texto_pregunta, texto_documento)
        puntuacion_jaccard = calcular_similitud_jaccard(texto_pregunta, texto_documento)

        # Calcular la puntuación combinada de relevancia
        puntuacion_relevancia = (puntuacion_coseno + puntuacion_jaccard) / 2

        # Agregar el documento con sus puntuaciones a la lista
        puntuaciones_relevancia.append({
            'id_documento': documento['id'],
            'titulo': documento['titulo'],
            'puntuacion_coseno': puntuacion_coseno,
            'puntuacion_jaccard': puntuacion_jaccard,
            'puntuacion_relevancia': puntuacion_relevancia
        })

    # Ordenar los documentos por la puntuación de relevancia en orden descendente
    puntuaciones_relevancia = sorted(puntuaciones_relevancia, key=lambda x: x['puntuacion_relevancia'], reverse=True)

    # Guardar solo los `k` documentos más relevantes para la pregunta actual
    rankings_relevancia[id_pregunta] = puntuaciones_relevancia[:limite_ranking]

# %%
# Mostrar el ranking de documentos para cada pregunta
for id_pregunta, documentos_ordenados in rankings_relevancia.items():
    print(f"\nRanking para la Pregunta {id_pregunta}: {preguntas[id_pregunta]}")
    for posicion, documento in enumerate(documentos_ordenados, start=1):
        print(f"  {posicion}. Documento {documento['id_documento']}: {documento['titulo']}")
        print(f"     Similitud Coseno: {documento['puntuacion_coseno']:.4f}")
        print(f"     Similitud de Jaccard: {documento['puntuacion_jaccard']:.4f}")
        print(f"     Puntuación Total de Relevancia: {documento['puntuacion_relevancia']:.4f}")
# Out:
# Ranking para la Pregunta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
#   1. Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#      Similitud Coseno: 0.6405
#      Similitud de Jaccard: 0.4706
#      Puntuación Total de Relevancia: 0.5556
#   2. Documento 7: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#      Similitud Coseno: 0.6405
#      Similitud de Jaccard: 0.4706
#      Puntuación Total de Relevancia: 0.5556
#   3. Documento 14: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#      Similitud Coseno: 0.6301
#      Similitud de Jaccard: 0.4500
#      Puntuación Total de Relevancia: 0.5401
#   4. Documento 11: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#      Similitud Coseno: 0.6172
#      Similitud de Jaccard: 0.4444
#      Puntuación Total de Relevancia: 0.5308
#   5. Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#      Similitud Coseno: 0.5809
#      Similitud de Jaccard: 0.3913
#      Puntuación Total de Relevancia: 0.4861
#   6. Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#      Similitud Coseno: 0.5217
#      Similitud de Jaccard: 0.3500
#      Puntuación Total de Relevancia: 0.4359
#   7. Documento 29: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#      Similitud Coseno: 0.5217
#      Similitud de Jaccard: 0.3500
#      Puntuación Total de Relevancia: 0.4359
#
# Ranking para la Pregunta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
#   1. Documento 15: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#      Similitud Coseno: 0.5547
#      Similitud de Jaccard: 0.3750
#      Puntuación Total de Relevancia: 0.4649
#   2. Documento 25: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#      Similitud Coseno: 0.4623
#      Similitud de Jaccard: 0.2941
#      Puntuación Total de Relevancia: 0.3782
#   3. Documento 8: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#      Similitud Coseno: 0.4303
#      Similitud de Jaccard: 0.2632
#      Puntuación Total de Relevancia: 0.3467
#   4. Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#      Similitud Coseno: 0.4167
#      Similitud de Jaccard: 0.2500
#      Puntuación Total de Relevancia: 0.3333
#   5. Documento 6: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#      Similitud Coseno: 0.3698
#      Similitud de Jaccard: 0.2222
#      Puntuación Total de Relevancia: 0.2960
#   6. Documento 17: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#      Similitud Coseno: 0.3698
#      Similitud de Jaccard: 0.2222
#      Puntuación Total de Relevancia: 0.2960
#   7. Documento 27: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#      Similitud Coseno: 0.3563
#      Similitud de Jaccard: 0.2105
#      Puntuación Total de Relevancia: 0.2834
#
# Ranking para la Pregunta 3: Estrategias universitarias para reducir el estrés en estudiantes
#   1. Documento 19: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#      Similitud Coseno: 0.4725
#      Similitud de Jaccard: 0.2941
#      Puntuación Total de Relevancia: 0.3833
#   2. Documento 24: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#      Similitud Coseno: 0.3922
#      Similitud de Jaccard: 0.2353
#      Puntuación Total de Relevancia: 0.3138
#   3. Documento 13: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#      Similitud Coseno: 0.3953
#      Similitud de Jaccard: 0.2174
#      Puntuación Total de Relevancia: 0.3063
#   4. Documento 5: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#      Similitud Coseno: 0.3536
#      Similitud de Jaccard: 0.2000
#      Puntuación Total de Relevancia: 0.2768
#   5. Documento 26: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#      Similitud Coseno: 0.3198
#      Similitud de Jaccard: 0.1875
#      Puntuación Total de Relevancia: 0.2537
#   6. Documento 2: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#      Similitud Coseno: 0.2942
#      Similitud de Jaccard: 0.1667
#      Puntuación Total de Relevancia: 0.2304
#   7. Documento 4: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#      Similitud Coseno: 0.2942
#      Similitud de Jaccard: 0.1667
#      Puntuación Total de Relevancia: 0.2304
