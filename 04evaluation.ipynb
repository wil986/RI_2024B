# %% [markdown]
# # Ejercicio 04: Evaluación de un Sistema de Recuperación de Información
#
# El objetivo de este ejercicio es evaluar la efectividad de un sistema de recuperación de información utilizando métricas como *precisión*, *recall*, *F1-score*, *Mean Average Precision (MAP)* y *Normalized Discounted Cumulative Gain (nDCG)*.
#
# Seguirás los siguientes pasos:

# %% [markdown]
# 1. Proporcionar un Conjunto de Datos:

# %%
import xml.etree.ElementTree as XmlParser
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances, cosine_similarity
import pandas as pd

# %%
# Lectura y procesamiento de datos desde XML
xml_document = XmlParser.parse('/content/sample_data/03ranking_corpus.xml')
xml_root = xml_document.getroot()

# Crear base de datos a partir del XML
dataset = []
for node in xml_root.findall('document'):
    identifier = node.get('id')
    heading = node.find('title').text
    tags = node.find('keywords').text.split(', ')
    dataset.append({
        'document_id': identifier,
        'heading': heading,
        'tags': tags
    })

# %%
# Mostrar información del dataset
print("Contenido del Dataset Procesado:")
for record in dataset:
    print(f"ID: {record['document_id']}, Título: {record['heading']}, Etiquetas: {record['tags']}")

# Definir consultas
query_list = [
    "beneficios de la telemedicina en salud crónica",
    "impacto de la nutrición en el rendimiento académico",
    "estrategias para mejorar la salud mental en estudiantes universitarios"
]

print("\nLista de Consultas:")
for query_idx, query_text in enumerate(query_list, start=1):
    print(f"Consulta {query_idx}: {query_text}")

# Definir relevancia de los documentos para cada consulta
relevance_mapping = {
    "Query 1": ["1", "10"],   # Documentos relevantes para la consulta 1
    "Query 2": ["2", "7"],    # Documentos relevantes para la consulta 2
    "Query 3": ["13", "14", "23"]  # Documentos relevantes para la consulta 3
}

print("\nMapeo de Relevancia de Documentos:")
for query_name, relevant_docs in relevance_mapping.items():
    print(f"{query_name}: Documentos relevantes -> {relevant_docs}")
# Out:
# Contenido del Dataset Procesado:
# ID: 1, Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas., Etiquetas: ['telemedicina', 'salud crónica', 'tratamiento', 'tecnología médica']
# ID: 2, Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes., Etiquetas: ['nutrición', 'rendimiento académico', 'salud mental', 'estudiantes']
# ID: 3, Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus., Etiquetas: ['amistad', 'bienestar estudiantil', 'campus', 'relaciones sociales']
# ID: 4, Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica., Etiquetas: ['bibliotecas universitarias', 'investigación', 'academia', 'recursos']
# ID: 5, Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés., Etiquetas: ['espacios verdes', 'campus universitario', 'concentración', 'estrés']
# ID: 6, Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes., Etiquetas: ['cultura universitaria', 'hábitos saludables', 'bienestar', 'estudiantes']
# ID: 7, Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios., Etiquetas: ['sueño', 'salud mental', 'rendimiento académico', 'universitarios']
# ID: 8, Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios., Etiquetas: ['apoyo familiar', 'apoyo social', 'bienestar emocional', 'estudiantes']
# ID: 9, Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos., Etiquetas: ['hábitos de lectura', 'desarrollo cognitivo', 'jóvenes', 'adultos']
# ID: 10, Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes., Etiquetas: ['tecnología médica', 'medicina preventiva', 'jóvenes', 'avances tecnológicos']
# ID: 11, Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios., Etiquetas: ['ejercicio', 'estrés académico', 'estudiantes universitarios', 'salud']
# ID: 12, Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios., Etiquetas: ['mindfulness', 'meditación', 'ansiedad', 'estudiantes universitarios']
# ID: 13, Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus., Etiquetas: ['salud mental', 'estudiantes universitarios', 'apoyo psicológico', 'grupos de estudio']
# ID: 14, Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico., Etiquetas: ['salud mental', 'desempeño académico', 'servicios universitarios', 'estudiantes']
# ID: 15, Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes., Etiquetas: ['actividades extracurriculares', 'bienestar emocional', 'social', 'estudiantes']
# ID: 16, Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas., Etiquetas: ['laboratorios de innovación', 'competencias tecnológicas', 'educación', 'desarrollo']
# ID: 17, Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración., Etiquetas: ['diseño de campus', 'interacción', 'colaboración', 'tendencias']
# ID: 18, Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian., Etiquetas: ['bienestar académico', 'estudiantes que trabajan', 'comparación', 'rendimiento']
# ID: 19, Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios., Etiquetas: ['agotamiento académico', 'factores de riesgo', 'prevención', 'estudiantes universitarios']
# ID: 20, Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes., Etiquetas: ['tecnología', 'redes sociales', 'calidad del sueño', 'estudiantes']
# ID: 21, Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades., Etiquetas: ['tecnologías verdes', 'edificios universitarios', 'impacto ambiental', 'sostenibilidad']
# ID: 22, Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad., Etiquetas: ['bicicletas compartidas', 'movilidad', 'universidades', 'transporte sostenible']
# ID: 23, Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar., Etiquetas: ['carga académica', 'salud emocional', 'estudiantes', 'apoyo universitario']
# ID: 24, Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas., Etiquetas: ['equilibrio', 'vida social', 'académica', 'estudiantes', 'estrategias']
# ID: 25, Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria., Etiquetas: ['actividades artísticas', 'bienestar psicológico', 'vida universitaria', 'creatividad']
# ID: 26, Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades., Etiquetas: ['programas de becas', 'retención de estudiantes', 'beneficios', 'universidades']
# ID: 27, Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes., Etiquetas: ['deportes', 'actividad física', 'integración social', 'estudiantes']
# ID: 28, Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés., Etiquetas: ['eventos de bienestar', 'talleres', 'reducción del estrés', 'universidad']
# ID: 29, Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios., Etiquetas: ['hábitos de sueño', 'rendimiento en exámenes', 'análisis', 'estudiantes']
# ID: 30, Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas., Etiquetas: ['inteligencia artificial', 'servicios médicos', 'comunidades remotas', 'tecnología']
#
# Lista de Consultas:
# Consulta 1: beneficios de la telemedicina en salud crónica
# Consulta 2: impacto de la nutrición en el rendimiento académico
# Consulta 3: estrategias para mejorar la salud mental en estudiantes universitarios
#
# Mapeo de Relevancia de Documentos:
# Query 1: Documentos relevantes -> ['1', '10']
# Query 2: Documentos relevantes -> ['2', '7']
# Query 3: Documentos relevantes -> ['13', '14', '23']

# %% [markdown]
# 2. Calcular Resultados de Búsqueda:

# %%
# Combinar títulos y keywords para cada documento en un solo texto
document_texts = [" ".join([doc['heading']] + doc['tags']) for doc in dataset]

# Vectorizar los textos de los documentos y las consultas con TF-IDF
vectorizer = TfidfVectorizer()
corpus_tfidf = vectorizer.fit_transform(document_texts)
query_tfidf = vectorizer.transform(query_list)

# Calcular distancias y similitudes
euclidean_dist = euclidean_distances(query_tfidf, corpus_tfidf)
cosine_sim = cosine_similarity(query_tfidf, corpus_tfidf)

# Mostrar matrices
print("\nMatriz de Distancia Euclidiana:")
print(pd.DataFrame(
    euclidean_dist,
    index=[f"Consulta {i+1}" for i in range(len(query_list))],
    columns=[f"Documento {i+1}" for i in range(len(dataset))]
))

print("\nMatriz de Similitud Coseno:")
print(pd.DataFrame(
    cosine_sim,
    index=[f"Consulta {i+1}" for i in range(len(query_list))],
    columns=[f"Documento {i+1}" for i in range(len(dataset))]
))
# Out:
# Matriz de Distancia Euclidiana:
#             Documento 1  Documento 2  Documento 3  Documento 4  Documento 5  \
# Consulta 1     0.944752     1.299586     1.386398     1.372879     1.395867
# Consulta 2     1.345996     0.836806     1.374316     1.348691     1.385194
# Consulta 3     1.291102     1.117378     1.390055     1.392815     1.316638
#
#             Documento 6  Documento 7  Documento 8  Documento 9  Documento 10  \
# Consulta 1     1.363431     1.286788     1.384989     1.372554      1.377949
# Consulta 2     1.349048     1.117503     1.372775     1.299199      1.374653
# Consulta 3     1.349783     1.062958     1.333769     1.398851      1.349887
#
#             ...  Documento 21  Documento 22  Documento 23  Documento 24  \
# Consulta 1  ...      1.387553      1.385360      1.300964      1.394407
# Consulta 2  ...      1.265502      1.373302      1.330045      1.392619
# Consulta 3  ...      1.379821      1.312753      1.253845      1.188927
#
#             Documento 25  Documento 26  Documento 27  Documento 28  \
# Consulta 1      1.385536      1.208790      1.367424      1.385179
# Consulta 2      1.373987      1.343851      1.354197      1.373587
# Consulta 3      1.384023      1.339824      1.354873      1.403173
#
#             Documento 29  Documento 30
# Consulta 1      1.369823      1.398150
# Consulta 2      1.243585      1.388816
# Consulta 3      1.355754      1.397306
#
# [3 rows x 30 columns]
#
# Matriz de Similitud Coseno:
#             Documento 1  Documento 2  Documento 3  Documento 4  Documento 5  \
# Consulta 1     0.553722     0.155539     0.038950     0.057601     0.025777
# Consulta 2     0.094147     0.649878     0.055627     0.090516     0.040619
# Consulta 3     0.166528     0.375733     0.033873     0.030033     0.133232
#
#             Documento 6  Documento 7  Documento 8  Documento 9  Documento 10  \
# Consulta 1     0.070527     0.172088     0.040902     0.058047      0.050629
# Consulta 2     0.090034     0.375593     0.057745     0.156041      0.055165
# Consulta 3     0.089042     0.435061     0.110530     0.021608      0.088902
#
#             ...  Documento 21  Documento 22  Documento 23  Documento 24  \
# Consulta 1  ...      0.037348      0.040389      0.153746      0.027815
# Consulta 2  ...      0.199253      0.057021      0.115491      0.030307
# Consulta 3  ...      0.048048      0.138339      0.213937      0.293227
#
#             Documento 25  Documento 26  Documento 27  Documento 28  \
# Consulta 1      0.040145      0.269414      0.065076      0.040639
# Consulta 2      0.056080      0.097033      0.083076      0.056629
# Consulta 3      0.042240      0.102436      0.082160      0.015553
#
#             Documento 29  Documento 30
# Consulta 1      0.061792      0.022589
# Consulta 2      0.226748      0.035595
# Consulta 3      0.080965      0.023767
#
# [3 rows x 30 columns]

# %%
# Ordenar y mostrar resultados por consulta
results = {}
for query_idx, query_text in enumerate(query_list):
    print(f"\nConsulta {query_idx + 1}: {query_text}")

    # Ordenar resultados por distancia euclidiana (menor distancia primero)
    euclidean_sorted = euclidean_dist[query_idx].argsort()
    euclidean_results = [dataset[idx]['document_id'] for idx in euclidean_sorted]
    print("\nDocumentos ordenados por Distancia Euclidiana:")
    for idx in euclidean_sorted:
        print(f"ID Documento: {dataset[idx]['document_id']}, Distancia: {euclidean_dist[query_idx][idx]:.4f}")

    # Ordenar resultados por similitud coseno (mayor similitud primero)
    cosine_sorted = cosine_sim[query_idx].argsort()[::-1]
    cosine_results = [dataset[idx]['document_id'] for idx in cosine_sorted]
    print("\nDocumentos ordenados por Similitud Coseno:")
    for idx in cosine_sorted:
        print(f"ID Documento: {dataset[idx]['document_id']}, Similitud: {cosine_sim[query_idx][idx]:.4f}")

    # Guardar resultados en un diccionario
    results[f"Consulta {query_idx + 1}"] = {
        "Distancia Euclidiana": euclidean_results,
        "Similitud Coseno": cosine_results
    }

# Mostrar resultados finales
print("\nResultados completos por consulta:")
for consulta, resultados in results.items():
    print(f"{consulta}:")
    print(f"  Distancia Euclidiana: {resultados['Distancia Euclidiana']}")
    print(f"  Similitud Coseno: {resultados['Similitud Coseno']}")
# Out:
# Consulta 1: beneficios de la telemedicina en salud crónica
#
# Documentos ordenados por Distancia Euclidiana:
# ID Documento: 1, Distancia: 0.9448
# ID Documento: 26, Distancia: 1.2088
# ID Documento: 7, Distancia: 1.2868
# ID Documento: 2, Distancia: 1.2996
# ID Documento: 23, Distancia: 1.3010
# ID Documento: 13, Distancia: 1.3053
# ID Documento: 11, Distancia: 1.3083
# ID Documento: 14, Distancia: 1.3085
# ID Documento: 15, Distancia: 1.3158
# ID Documento: 12, Distancia: 1.3511
# ID Documento: 20, Distancia: 1.3588
# ID Documento: 6, Distancia: 1.3634
# ID Documento: 27, Distancia: 1.3674
# ID Documento: 29, Distancia: 1.3698
# ID Documento: 16, Distancia: 1.3722
# ID Documento: 9, Distancia: 1.3726
# ID Documento: 4, Distancia: 1.3729
# ID Documento: 17, Distancia: 1.3773
# ID Documento: 10, Distancia: 1.3779
# ID Documento: 8, Distancia: 1.3850
# ID Documento: 28, Distancia: 1.3852
# ID Documento: 22, Distancia: 1.3854
# ID Documento: 25, Distancia: 1.3855
# ID Documento: 3, Distancia: 1.3864
# ID Documento: 19, Distancia: 1.3865
# ID Documento: 21, Distancia: 1.3876
# ID Documento: 24, Distancia: 1.3944
# ID Documento: 5, Distancia: 1.3959
# ID Documento: 30, Distancia: 1.3981
# ID Documento: 18, Distancia: 1.4070
#
# Documentos ordenados por Similitud Coseno:
# ID Documento: 1, Similitud: 0.5537
# ID Documento: 26, Similitud: 0.2694
# ID Documento: 7, Similitud: 0.1721
# ID Documento: 2, Similitud: 0.1555
# ID Documento: 23, Similitud: 0.1537
# ID Documento: 13, Similitud: 0.1481
# ID Documento: 11, Similitud: 0.1442
# ID Documento: 14, Similitud: 0.1439
# ID Documento: 15, Similitud: 0.1344
# ID Documento: 12, Similitud: 0.0872
# ID Documento: 20, Similitud: 0.0768
# ID Documento: 6, Similitud: 0.0705
# ID Documento: 27, Similitud: 0.0651
# ID Documento: 29, Similitud: 0.0618
# ID Documento: 16, Similitud: 0.0585
# ID Documento: 9, Similitud: 0.0580
# ID Documento: 4, Similitud: 0.0576
# ID Documento: 17, Similitud: 0.0515
# ID Documento: 10, Similitud: 0.0506
# ID Documento: 8, Similitud: 0.0409
# ID Documento: 28, Similitud: 0.0406
# ID Documento: 22, Similitud: 0.0404
# ID Documento: 25, Similitud: 0.0401
# ID Documento: 3, Similitud: 0.0390
# ID Documento: 19, Similitud: 0.0388
# ID Documento: 21, Similitud: 0.0373
# ID Documento: 24, Similitud: 0.0278
# ID Documento: 5, Similitud: 0.0258
# ID Documento: 30, Similitud: 0.0226
# ID Documento: 18, Similitud: 0.0102
#
# Consulta 2: impacto de la nutrición en el rendimiento académico
#
# Documentos ordenados por Distancia Euclidiana:
# ID Documento: 2, Distancia: 0.8368
# ID Documento: 7, Distancia: 1.1175
# ID Documento: 11, Distancia: 1.1835
# ID Documento: 29, Distancia: 1.2436
# ID Documento: 21, Distancia: 1.2655
# ID Documento: 18, Distancia: 1.2756
# ID Documento: 14, Distancia: 1.2773
# ID Documento: 20, Distancia: 1.2808
# ID Documento: 19, Distancia: 1.2956
# ID Documento: 9, Distancia: 1.2992
# ID Documento: 23, Distancia: 1.3300
# ID Documento: 12, Distancia: 1.3351
# ID Documento: 26, Distancia: 1.3439
# ID Documento: 1, Distancia: 1.3460
# ID Documento: 4, Distancia: 1.3487
# ID Documento: 6, Distancia: 1.3490
# ID Documento: 13, Distancia: 1.3496
# ID Documento: 16, Distancia: 1.3514
# ID Documento: 27, Distancia: 1.3542
# ID Documento: 17, Distancia: 1.3649
# ID Documento: 8, Distancia: 1.3728
# ID Documento: 22, Distancia: 1.3733
# ID Documento: 28, Distancia: 1.3736
# ID Documento: 25, Distancia: 1.3740
# ID Documento: 3, Distancia: 1.3743
# ID Documento: 10, Distancia: 1.3747
# ID Documento: 15, Distancia: 1.3809
# ID Documento: 5, Distancia: 1.3852
# ID Documento: 30, Distancia: 1.3888
# ID Documento: 24, Distancia: 1.3926
#
# Documentos ordenados por Similitud Coseno:
# ID Documento: 2, Similitud: 0.6499
# ID Documento: 7, Similitud: 0.3756
# ID Documento: 11, Similitud: 0.2996
# ID Documento: 29, Similitud: 0.2267
# ID Documento: 21, Similitud: 0.1993
# ID Documento: 18, Similitud: 0.1864
# ID Documento: 14, Similitud: 0.1843
# ID Documento: 20, Similitud: 0.1798
# ID Documento: 19, Similitud: 0.1608
# ID Documento: 9, Similitud: 0.1560
# ID Documento: 23, Similitud: 0.1155
# ID Documento: 12, Similitud: 0.1088
# ID Documento: 26, Similitud: 0.0970
# ID Documento: 1, Similitud: 0.0941
# ID Documento: 4, Similitud: 0.0905
# ID Documento: 6, Similitud: 0.0900
# ID Documento: 13, Similitud: 0.0893
# ID Documento: 16, Similitud: 0.0869
# ID Documento: 27, Similitud: 0.0831
# ID Documento: 17, Similitud: 0.0685
# ID Documento: 8, Similitud: 0.0577
# ID Documento: 22, Similitud: 0.0570
# ID Documento: 28, Similitud: 0.0566
# ID Documento: 25, Similitud: 0.0561
# ID Documento: 3, Similitud: 0.0556
# ID Documento: 10, Similitud: 0.0552
# ID Documento: 15, Similitud: 0.0465
# ID Documento: 5, Similitud: 0.0406
# ID Documento: 30, Similitud: 0.0356
# ID Documento: 24, Similitud: 0.0303
#
# Consulta 3: estrategias para mejorar la salud mental en estudiantes universitarios
#
# Documentos ordenados por Distancia Euclidiana:
# ID Documento: 13, Distancia: 0.9476
# ID Documento: 7, Distancia: 1.0630
# ID Documento: 14, Distancia: 1.0688
# ID Documento: 2, Distancia: 1.1174
# ID Documento: 24, Distancia: 1.1889
# ID Documento: 19, Distancia: 1.2207
# ID Documento: 11, Distancia: 1.2227
# ID Documento: 23, Distancia: 1.2538
# ID Documento: 12, Distancia: 1.2635
# ID Documento: 1, Distancia: 1.2911
# ID Documento: 22, Distancia: 1.3128
# ID Documento: 5, Distancia: 1.3166
# ID Documento: 8, Distancia: 1.3338
# ID Documento: 26, Distancia: 1.3398
# ID Documento: 20, Distancia: 1.3456
# ID Documento: 6, Distancia: 1.3498
# ID Documento: 10, Distancia: 1.3499
# ID Documento: 15, Distancia: 1.3504
# ID Documento: 27, Distancia: 1.3549
# ID Documento: 29, Distancia: 1.3558
# ID Documento: 17, Distancia: 1.3691
# ID Documento: 18, Distancia: 1.3783
# ID Documento: 21, Distancia: 1.3798
# ID Documento: 25, Distancia: 1.3840
# ID Documento: 3, Distancia: 1.3901
# ID Documento: 4, Distancia: 1.3928
# ID Documento: 30, Distancia: 1.3973
# ID Documento: 9, Distancia: 1.3989
# ID Documento: 28, Distancia: 1.4032
# ID Documento: 16, Distancia: 1.4068
#
# Documentos ordenados por Similitud Coseno:
# ID Documento: 13, Similitud: 0.5511
# ID Documento: 7, Similitud: 0.4351
# ID Documento: 14, Similitud: 0.4289
# ID Documento: 2, Similitud: 0.3757
# ID Documento: 24, Similitud: 0.2932
# ID Documento: 19, Similitud: 0.2549
# ID Documento: 11, Similitud: 0.2525
# ID Documento: 23, Similitud: 0.2139
# ID Documento: 12, Similitud: 0.2018
# ID Documento: 1, Similitud: 0.1665
# ID Documento: 22, Similitud: 0.1383
# ID Documento: 5, Similitud: 0.1332
# ID Documento: 8, Similitud: 0.1105
# ID Documento: 26, Similitud: 0.1024
# ID Documento: 20, Similitud: 0.0947
# ID Documento: 6, Similitud: 0.0890
# ID Documento: 10, Similitud: 0.0889
# ID Documento: 15, Similitud: 0.0882
# ID Documento: 27, Similitud: 0.0822
# ID Documento: 29, Similitud: 0.0810
# ID Documento: 17, Similitud: 0.0628
# ID Documento: 18, Similitud: 0.0502
# ID Documento: 21, Similitud: 0.0480
# ID Documento: 25, Similitud: 0.0422
# ID Documento: 3, Similitud: 0.0339
# ID Documento: 4, Similitud: 0.0300
# ID Documento: 30, Similitud: 0.0238
# ID Documento: 9, Similitud: 0.0216
# ID Documento: 28, Similitud: 0.0156
# ID Documento: 16, Similitud: 0.0105
#
# Resultados completos por consulta:
# Consulta 1:
#   Distancia Euclidiana: ['1', '26', '7', '2', '23', '13', '11', '14', '15', '12', '20', '6', '27', '29', '16', '9', '4', '17', '10', '8', '28', '22', '25', '3', '19', '21', '24', '5', '30', '18']
#   Similitud Coseno: ['1', '26', '7', '2', '23', '13', '11', '14', '15', '12', '20', '6', '27', '29', '16', '9', '4', '17', '10', '8', '28', '22', '25', '3', '19', '21', '24', '5', '30', '18']
# Consulta 2:
#   Distancia Euclidiana: ['2', '7', '11', '29', '21', '18', '14', '20', '19', '9', '23', '12', '26', '1', '4', '6', '13', '16', '27', '17', '8', '22', '28', '25', '3', '10', '15', '5', '30', '24']
#   Similitud Coseno: ['2', '7', '11', '29', '21', '18', '14', '20', '19', '9', '23', '12', '26', '1', '4', '6', '13', '16', '27', '17', '8', '22', '28', '25', '3', '10', '15', '5', '30', '24']
# Consulta 3:
#   Distancia Euclidiana: ['13', '7', '14', '2', '24', '19', '11', '23', '12', '1', '22', '5', '8', '26', '20', '6', '10', '15', '27', '29', '17', '18', '21', '25', '3', '4', '30', '9', '28', '16']
#   Similitud Coseno: ['13', '7', '14', '2', '24', '19', '11', '23', '12', '1', '22', '5', '8', '26', '20', '6', '10', '15', '27', '29', '17', '18', '21', '25', '3', '4', '30', '9', '28', '16']

# %% [markdown]
# 3. Calcular las Métricas de Evaluación:

# %%
from sklearn.metrics import ndcg_score

# Función para evaluar los resultados de recuperación
def evaluar_sistema(resultados_ranking, documentos_relevantes, top_k=5):
    # Documentos relevantes encontrados en el top-k
    encontrados_relevantes = sum(1 for doc in resultados_ranking[:top_k] if doc in documentos_relevantes)
    total_relevantes = len(documentos_relevantes)

    # Precisión en el top-k
    precision_top_k = encontrados_relevantes / top_k if top_k > 0 else 0

    # Recall (Tasa de Recuperación)
    tasa_recuperacion = encontrados_relevantes / total_relevantes if total_relevantes > 0 else 0

    # F1-score como balance entre precisión y recall
    f1_balance = (2 * precision_top_k * tasa_recuperacion) / (precision_top_k + tasa_recuperacion) if (precision_top_k + tasa_recuperacion) > 0 else 0

    # Mean Average Precision (MAP)
    acumulado_precisiones = 0
    relevantes_acumulados = 0
    for posicion, documento in enumerate(resultados_ranking[:top_k]):
        if documento in documentos_relevantes:
            relevantes_acumulados += 1
            acumulado_precisiones += relevantes_acumulados / (posicion + 1)
    promedio_precision = acumulado_precisiones / total_relevantes if total_relevantes > 0 else 0

    # nDCG: Normalized Discounted Cumulative Gain
    relevancias_binarias = [1 if doc in documentos_relevantes else 0 for doc in resultados_ranking[:top_k]]
    ndcg_valor = ndcg_score([relevancias_binarias], [list(range(top_k))], k=top_k)

    return precision_top_k, tasa_recuperacion, f1_balance, promedio_precision, ndcg_valor

# Juicios de relevancia para las consultas
relevancia_esperada = {
    "Consulta 1": ["1", "10"],
    "Consulta 2": ["2", "7"],
    "Consulta 3": ["13", "14", "23"]
}

# %%
# Evaluar los sistemas para cada consulta y mostrar resultados
print("\nEvaluación de Sistemas de Recuperación:")
for numero_consulta, texto_consulta in enumerate(query_list, start=1):
    documentos_relevantes = relevancia_esperada[f"Consulta {numero_consulta}"]

    print(f"\nConsulta {numero_consulta}: '{texto_consulta}'")

    # Resultados para Distancia Euclidiana
    ranking_euclidiana = results[f"Consulta {numero_consulta}"]["Distancia Euclidiana"]
    precision_eu, recall_eu, f1_eu, map_eu, ndcg_eu = evaluar_sistema(ranking_euclidiana, documentos_relevantes)
    print(f"\nDistancia Euclidiana:")
    print(f"Prec@k: {precision_eu:.4f}, Recall: {recall_eu:.4f}, F1-score: {f1_eu:.4f}, MAP: {map_eu:.4f}, nDCG: {ndcg_eu:.4f}")

    # Resultados para Similitud Coseno
    ranking_coseno = results[f"Consulta {numero_consulta}"]["Similitud Coseno"]
    precision_cos, recall_cos, f1_cos, map_cos, ndcg_cos = evaluar_sistema(ranking_coseno, documentos_relevantes)
    print(f"\nSimilitud Coseno:")
    print(f"Prec@k: {precision_cos:.4f}, Recall: {recall_cos:.4f}, F1-score: {f1_cos:.4f}, MAP: {map_cos:.4f}, nDCG: {ndcg_cos:.4f}")

    # Resumen comparativo
    mejor_sistema = "Distancia Euclidiana" if f1_eu > f1_cos else "Similitud Coseno" if f1_cos > f1_eu else "Empate"
    print(f"\nMejor desempeño: {mejor_sistema}")
# Out:
# Evaluación de Sistemas de Recuperación:
#
# Consulta 1: 'beneficios de la telemedicina en salud crónica'
#
# Distancia Euclidiana:
# Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
#
# Similitud Coseno:
# Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
#
# Mejor desempeño: Empate
#
# Consulta 2: 'impacto de la nutrición en el rendimiento académico'
#
# Distancia Euclidiana:
# Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
#
# Similitud Coseno:
# Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
#
# Mejor desempeño: Empate
#
# Consulta 3: 'estrategias para mejorar la salud mental en estudiantes universitarios'
#
# Distancia Euclidiana:
# Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438
#
# Similitud Coseno:
# Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438
#
# Mejor desempeño: Empate

# %% [markdown]
# 4. Análisis y Comparación:

# %%
print("\nComparativa de Desempeño entre Sistemas de Recuperación:")

for indice, consulta_texto in enumerate(query_list):
    documentos_relevantes = juicios_relevancia[f"Consulta {indice + 1}"]

    print(f"\nEvaluación de la Consulta {indice + 1}: '{consulta_texto}'")

    # Recuperar los resultados para ambos métodos
    resultados_euclidiana = results[f"Consulta {indice + 1}"]["Distancia Euclidiana"]
    resultados_coseno = results[f"Consulta {indice + 1}"]["Similitud Coseno"]

    # Calcular métricas para Distancia Euclidiana
    metrica_euclidiana = calcular_metricas(resultados_euclidiana, documentos_relevantes)
    precision_euc, recall_euc, f1_euc, map_euc, ndcg_euc = metrica_euclidiana

    # Calcular métricas para Similitud Coseno
    metrica_coseno = calcular_metricas(resultados_coseno, documentos_relevantes)
    precision_cos, recall_cos, f1_cos, map_cos, ndcg_cos = metrica_coseno

    # Análisis basado en F1-score
    print("\nResultados Comparativos:")
    if f1_euc > f1_cos:
        print("→ El sistema basado en Distancia Euclidiana ofrece un mejor desempeño para esta consulta.")
    elif f1_cos > f1_euc:
        print("→ El sistema basado en Similitud Coseno ofrece un mejor desempeño para esta consulta.")
    else:
        print("→ Ambos sistemas presentan un desempeño equivalente en esta consulta.")

    # Mostrar métricas detalladas para ambos sistemas
    print("\nMétricas Detalladas:")
    print(f"Distancia Euclidiana - Prec@k: {precision_euc:.4f}, Recall: {recall_euc:.4f}, F1-score: {f1_euc:.4f}, MAP: {map_euc:.4f}, nDCG: {ndcg_euc:.4f}")
    print(f"Similitud Coseno    - Prec@k: {precision_cos:.4f}, Recall: {recall_cos:.4f}, F1-score: {f1_cos:.4f}, MAP: {map_cos:.4f}, nDCG: {ndcg_cos:.4f}")

    # Adicional: Resumen en una estructura legible
    print(f"\nResumen para la Consulta {indice + 1}:")
    print(f"- Mejor sistema: {'Distancia Euclidiana' if f1_euc > f1_cos else 'Similitud Coseno' if f1_cos > f1_euc else 'Empate'}")
    print(f"- F1-score: Euclidiana={f1_euc:.4f}, Coseno={f1_cos:.4f}")
# Out:
# Comparativa de Desempeño entre Sistemas de Recuperación:
#
# Evaluación de la Consulta 1: 'beneficios de la telemedicina en salud crónica'
#
# Resultados Comparativos:
# → Ambos sistemas presentan un desempeño equivalente en esta consulta.
#
# Métricas Detalladas:
# Distancia Euclidiana - Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
# Similitud Coseno    - Prec@k: 0.2000, Recall: 0.5000, F1-score: 0.2857, MAP: 0.5000, nDCG: 0.3869
#
# Resumen para la Consulta 1:
# - Mejor sistema: Empate
# - F1-score: Euclidiana=0.2857, Coseno=0.2857
#
# Evaluación de la Consulta 2: 'impacto de la nutrición en el rendimiento académico'
#
# Resultados Comparativos:
# → Ambos sistemas presentan un desempeño equivalente en esta consulta.
#
# Métricas Detalladas:
# Distancia Euclidiana - Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
# Similitud Coseno    - Prec@k: 0.4000, Recall: 1.0000, F1-score: 0.5714, MAP: 1.0000, nDCG: 0.5013
#
# Resumen para la Consulta 2:
# - Mejor sistema: Empate
# - F1-score: Euclidiana=0.5714, Coseno=0.5714
#
# Evaluación de la Consulta 3: 'estrategias para mejorar la salud mental en estudiantes universitarios'
#
# Resultados Comparativos:
# → Ambos sistemas presentan un desempeño equivalente en esta consulta.
#
# Métricas Detalladas:
# Distancia Euclidiana - Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438
# Similitud Coseno    - Prec@k: 0.4000, Recall: 0.6667, F1-score: 0.5000, MAP: 0.5556, nDCG: 0.5438
#
# Resumen para la Consulta 3:
# - Mejor sistema: Empate
# - F1-score: Euclidiana=0.5000, Coseno=0.5000
